# %% [markdown]
# # Extracción de HOG para el dataset

# %%
import cv2
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import shutil
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from  PIL  import Image
from sklearn.preprocessing import MinMaxScaler
import h5py
from time import sleep

# %%
images_path = '/content/drive/MyDrive/Dataset'
class_names = os.listdir(images_path)
class_names.sort()
print(class_names)
# Out:
# ['closed', 'open']

# %%
# feature-descriptor-3: Color Histogram
def fd_histogram(image, mask=None):
    # convert the image to HSV color-space
    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    # compute the color histogram
    hist  = cv2.calcHist([image], [0, 1, 2], None, [bins, bins, bins], [0, 256, 0, 256, 0, 256])
    # normalize the histogram
    cv2.normalize(hist, hist)
    # return the histogram
    return hist.flatten()

# %%
color_features = []
color_features_labels   = []

# %%
print("[STATUS] Started extracting color features..")
for class_name in class_names:
    cur_path = images_path + "/" + class_name
    cur_label = class_name
    i = 1

    for file in glob.glob(cur_path + "/*.png"):
        print("Processing Image - {} in {}".format(i, cur_label))
        # read the training image
        image = cv2.imread(file)

        # extract color feature from the image
        bins = 8
        hist = fd_histogram(image)

        # append the feature vector and label
        color_features.append(hist)
        color_features_labels.append(cur_label)

        # show loop update
        i += 1
# Out:
# [STATUS] Started extracting color features..
# Processing Image - 1 in closed
# Processing Image - 2 in closed
# Processing Image - 3 in closed
# Processing Image - 4 in closed
# Processing Image - 5 in closed
# Processing Image - 6 in closed
# Processing Image - 7 in closed
# Processing Image - 8 in closed
# Processing Image - 9 in closed
# Processing Image - 10 in closed
# Processing Image - 11 in closed
# Processing Image - 12 in closed
# Processing Image - 13 in closed
# Processing Image - 14 in closed
# Processing Image - 15 in closed
# Processing Image - 16 in closed
# Processing Image - 17 in closed
# Processing Image - 18 in closed
# Processing Image - 19 in closed
# Processing Image - 20 in closed
# Processing Image - 21 in closed
# Processing Image - 22 in closed
# Processing Image - 23 in closed
# Processing Image - 24 in closed
# Processing Image - 25 in closed
# Processing Image - 26 in closed
# Processing Image - 27 in closed
# Processing Image - 28 in closed
# Processing Image - 29 in closed
# Processing Image - 30 in closed
# Processing Image - 31 in closed
# Processing Image - 32 in closed
# Processing Image - 33 in closed
# Processing Image - 34 in closed
# Processing Image - 35 in closed
# Processing Image - 36 in closed
# Processing Image - 37 in closed
# Processing Image - 38 in closed
# Processing Image - 39 in closed
# Processing Image - 40 in closed
# Processing Image - 41 in closed
# Processing Image - 42 in closed
# Processing Image - 43 in closed
# Processing Image - 44 in closed
# Processing Image - 45 in closed
# Processing Image - 46 in closed
# Processing Image - 47 in closed
# Processing Image - 48 in closed
# Processing Image - 49 in closed
# Processing Image - 50 in closed
# Processing Image - 51 in closed
# Processing Image - 52 in closed
# Processing Image - 53 in closed
# Processing Image - 54 in closed
# Processing Image - 55 in closed
# Processing Image - 56 in closed
# Processing Image - 57 in closed
# Processing Image - 58 in closed
# Processing Image - 59 in closed
# Processing Image - 60 in closed
# Processing Image - 61 in closed
# Processing Image - 62 in closed
# Processing Image - 63 in closed
# Processing Image - 64 in closed
# Processing Image - 65 in closed
# Processing Image - 66 in closed
# Processing Image - 67 in closed
# Processing Image - 68 in closed
# Processing Image - 69 in closed
# Processing Image - 70 in closed
# Processing Image - 71 in closed
# Processing Image - 72 in closed
# Processing Image - 73 in closed
# Processing Image - 74 in closed
# Processing Image - 75 in closed
# Processing Image - 76 in closed
# Processing Image - 77 in closed
# Processing Image - 78 in closed
# Processing Image - 79 in closed
# Processing Image - 80 in closed
# Processing Image - 81 in closed
# Processing Image - 82 in closed
# Processing Image - 83 in closed
# Processing Image - 84 in closed
# Processing Image - 85 in closed
# Processing Image - 86 in closed
# Processing Image - 87 in closed
# Processing Image - 88 in closed
# Processing Image - 89 in closed
# Processing Image - 90 in closed
# Processing Image - 91 in closed
# Processing Image - 92 in closed
# Processing Image - 93 in closed
# Processing Image - 94 in closed
# Processing Image - 95 in closed
# Processing Image - 96 in closed
# Processing Image - 97 in closed
# Processing Image - 98 in closed
# Processing Image - 99 in closed
# Processing Image - 100 in closed
# Processing Image - 101 in closed
# Processing Image - 102 in closed
# Processing Image - 103 in closed
# Processing Image - 104 in closed
# Processing Image - 105 in closed
# Processing Image - 106 in closed
# Processing Image - 107 in closed
# Processing Image - 108 in closed
# Processing Image - 109 in closed
# Processing Image - 110 in closed
# Processing Image - 111 in closed
# Processing Image - 112 in closed
# Processing Image - 113 in closed
# Processing Image - 114 in closed
# Processing Image - 115 in closed
# Processing Image - 116 in closed
# Processing Image - 117 in closed
# Processing Image - 118 in closed
# Processing Image - 119 in closed
# Processing Image - 120 in closed
# Processing Image - 121 in closed
# Processing Image - 122 in closed
# Processing Image - 123 in closed
# Processing Image - 124 in closed
# Processing Image - 125 in closed
# Processing Image - 126 in closed
# Processing Image - 127 in closed
# Processing Image - 128 in closed
# Processing Image - 129 in closed
# Processing Image - 130 in closed
# Processing Image - 131 in closed
# Processing Image - 132 in closed
# Processing Image - 133 in closed
# Processing Image - 134 in closed
# Processing Image - 135 in closed
# Processing Image - 136 in closed
# Processing Image - 137 in closed
# Processing Image - 138 in closed
# Processing Image - 139 in closed
# Processing Image - 140 in closed
# Processing Image - 141 in closed
# Processing Image - 142 in closed
# Processing Image - 143 in closed
# Processing Image - 144 in closed
# Processing Image - 145 in closed
# Processing Image - 146 in closed
# Processing Image - 147 in closed
# Processing Image - 148 in closed
# Processing Image - 149 in closed
# Processing Image - 150 in closed
# Processing Image - 151 in closed
# Processing Image - 152 in closed
# Processing Image - 153 in closed
# Processing Image - 154 in closed
# Processing Image - 155 in closed
# Processing Image - 156 in closed
# Processing Image - 157 in closed
# Processing Image - 158 in closed
# Processing Image - 159 in closed
# Processing Image - 160 in closed
# Processing Image - 161 in closed
# Processing Image - 162 in closed
# Processing Image - 163 in closed
# Processing Image - 164 in closed
# Processing Image - 165 in closed
# Processing Image - 166 in closed
# Processing Image - 167 in closed
# Processing Image - 168 in closed
# Processing Image - 169 in closed
# Processing Image - 170 in closed
# Processing Image - 171 in closed
# Processing Image - 172 in closed
# Processing Image - 173 in closed
# Processing Image - 174 in closed
# Processing Image - 175 in closed
# Processing Image - 176 in closed
# Processing Image - 177 in closed
# Processing Image - 178 in closed
# Processing Image - 179 in closed
# Processing Image - 180 in closed
# Processing Image - 181 in closed
# Processing Image - 182 in closed
# Processing Image - 183 in closed
# Processing Image - 184 in closed
# Processing Image - 185 in closed
# Processing Image - 186 in closed
# Processing Image - 187 in closed
# Processing Image - 188 in closed
# Processing Image - 189 in closed
# Processing Image - 190 in closed
# Processing Image - 191 in closed
# Processing Image - 192 in closed
# Processing Image - 193 in closed
# Processing Image - 194 in closed
# Processing Image - 195 in closed
# Processing Image - 196 in closed
# Processing Image - 197 in closed
# Processing Image - 198 in closed
# Processing Image - 199 in closed
# Processing Image - 200 in closed
# Processing Image - 201 in closed
# Processing Image - 202 in closed
# Processing Image - 203 in closed
# Processing Image - 204 in closed
# Processing Image - 205 in closed
# Processing Image - 206 in closed
# Processing Image - 207 in closed
# Processing Image - 208 in closed
# Processing Image - 209 in closed
# Processing Image - 210 in closed
# Processing Image - 211 in closed
# Processing Image - 212 in closed
# Processing Image - 213 in closed
# Processing Image - 214 in closed
# Processing Image - 215 in closed
# Processing Image - 216 in closed
# Processing Image - 217 in closed
# Processing Image - 218 in closed
# Processing Image - 219 in closed
# Processing Image - 220 in closed
# Processing Image - 221 in closed
# Processing Image - 222 in closed
# Processing Image - 223 in closed
# Processing Image - 224 in closed
# Processing Image - 225 in closed
# Processing Image - 226 in closed
# Processing Image - 227 in closed
# Processing Image - 228 in closed
# Processing Image - 229 in closed
# Processing Image - 230 in closed
# Processing Image - 231 in closed
# Processing Image - 232 in closed
# Processing Image - 233 in closed
# Processing Image - 234 in closed
# Processing Image - 235 in closed
# Processing Image - 236 in closed
# Processing Image - 237 in closed
# Processing Image - 238 in closed
# Processing Image - 239 in closed
# Processing Image - 240 in closed
# Processing Image - 241 in closed
# Processing Image - 242 in closed
# Processing Image - 243 in closed
# Processing Image - 244 in closed
# Processing Image - 245 in closed
# Processing Image - 246 in closed
# Processing Image - 247 in closed
# Processing Image - 248 in closed
# Processing Image - 249 in closed
# Processing Image - 250 in closed
# Processing Image - 251 in closed
# Processing Image - 252 in closed
# Processing Image - 253 in closed
# Processing Image - 254 in closed
# Processing Image - 255 in closed
# Processing Image - 256 in closed
# Processing Image - 257 in closed
# Processing Image - 258 in closed
# Processing Image - 259 in closed
# Processing Image - 260 in closed
# Processing Image - 261 in closed
# Processing Image - 262 in closed
# Processing Image - 263 in closed
# Processing Image - 264 in closed
# Processing Image - 265 in closed
# Processing Image - 266 in closed
# Processing Image - 267 in closed
# Processing Image - 268 in closed
# Processing Image - 269 in closed
# Processing Image - 270 in closed
# Processing Image - 271 in closed
# Processing Image - 272 in closed
# Processing Image - 273 in closed
# Processing Image - 274 in closed
# Processing Image - 275 in closed
# Processing Image - 276 in closed
# Processing Image - 277 in closed
# Processing Image - 278 in closed
# Processing Image - 279 in closed
# Processing Image - 280 in closed
# Processing Image - 281 in closed
# Processing Image - 282 in closed
# Processing Image - 283 in closed
# Processing Image - 284 in closed
# Processing Image - 285 in closed
# Processing Image - 286 in closed
# Processing Image - 287 in closed
# Processing Image - 288 in closed
# Processing Image - 289 in closed
# Processing Image - 290 in closed
# Processing Image - 291 in closed
# Processing Image - 292 in closed
# Processing Image - 293 in closed
# Processing Image - 294 in closed
# Processing Image - 295 in closed
# Processing Image - 296 in closed
# Processing Image - 297 in closed
# Processing Image - 298 in closed
# Processing Image - 299 in closed
# Processing Image - 300 in closed
# Processing Image - 301 in closed
# Processing Image - 302 in closed
# Processing Image - 303 in closed
# Processing Image - 304 in closed
# Processing Image - 305 in closed
# Processing Image - 306 in closed
# Processing Image - 307 in closed
# Processing Image - 308 in closed
# Processing Image - 309 in closed
# Processing Image - 310 in closed
# Processing Image - 311 in closed
# Processing Image - 312 in closed
# Processing Image - 313 in closed
# Processing Image - 314 in closed
# Processing Image - 315 in closed
# Processing Image - 316 in closed
# Processing Image - 317 in closed
# Processing Image - 318 in closed
# Processing Image - 319 in closed
# Processing Image - 320 in closed
# Processing Image - 321 in closed
# Processing Image - 322 in closed
# Processing Image - 323 in closed
# Processing Image - 324 in closed
# Processing Image - 325 in closed
# Processing Image - 326 in closed
# Processing Image - 327 in closed
# Processing Image - 328 in closed
# Processing Image - 329 in closed
# Processing Image - 330 in closed
# Processing Image - 331 in closed
# Processing Image - 332 in closed
# Processing Image - 333 in closed
# Processing Image - 334 in closed
# Processing Image - 335 in closed
# Processing Image - 336 in closed
# Processing Image - 337 in closed
# Processing Image - 338 in closed
# Processing Image - 339 in closed
# Processing Image - 340 in closed
# Processing Image - 341 in closed
# Processing Image - 342 in closed
# Processing Image - 343 in closed
# Processing Image - 344 in closed
# Processing Image - 345 in closed
# Processing Image - 346 in closed
# Processing Image - 347 in closed
# Processing Image - 348 in closed
# Processing Image - 349 in closed
# Processing Image - 350 in closed
# Processing Image - 351 in closed
# Processing Image - 352 in closed
# Processing Image - 353 in closed
# Processing Image - 354 in closed
# Processing Image - 355 in closed
# Processing Image - 356 in closed
# Processing Image - 357 in closed
# Processing Image - 358 in closed
# Processing Image - 359 in closed
# Processing Image - 360 in closed
# Processing Image - 361 in closed
# Processing Image - 362 in closed
# Processing Image - 363 in closed
# Processing Image - 364 in closed
# Processing Image - 365 in closed
# Processing Image - 366 in closed
# Processing Image - 367 in closed
# Processing Image - 368 in closed
# Processing Image - 369 in closed
# Processing Image - 370 in closed
# Processing Image - 371 in closed
# Processing Image - 372 in closed
# Processing Image - 373 in closed
# Processing Image - 374 in closed
# Processing Image - 375 in closed
# Processing Image - 376 in closed
# Processing Image - 377 in closed
# Processing Image - 378 in closed
# Processing Image - 379 in closed
# Processing Image - 380 in closed
# Processing Image - 381 in closed
# Processing Image - 382 in closed
# Processing Image - 383 in closed
# Processing Image - 384 in closed
# Processing Image - 385 in closed
# Processing Image - 386 in closed
# Processing Image - 387 in closed
# Processing Image - 388 in closed
# Processing Image - 389 in closed
# Processing Image - 390 in closed
# Processing Image - 391 in closed
# Processing Image - 392 in closed
# Processing Image - 393 in closed
# Processing Image - 394 in closed
# Processing Image - 395 in closed
# Processing Image - 396 in closed
# Processing Image - 397 in closed
# Processing Image - 398 in closed
# Processing Image - 399 in closed
# Processing Image - 400 in closed
# Processing Image - 401 in closed
# Processing Image - 402 in closed
# Processing Image - 403 in closed
# Processing Image - 404 in closed
# Processing Image - 405 in closed
# Processing Image - 406 in closed
# Processing Image - 407 in closed
# Processing Image - 408 in closed
# Processing Image - 409 in closed
# Processing Image - 410 in closed
# Processing Image - 411 in closed
# Processing Image - 412 in closed
# Processing Image - 413 in closed
# Processing Image - 414 in closed
# Processing Image - 415 in closed
# Processing Image - 416 in closed
# Processing Image - 417 in closed
# Processing Image - 418 in closed
# Processing Image - 419 in closed
# Processing Image - 420 in closed
# Processing Image - 421 in closed
# Processing Image - 422 in closed
# Processing Image - 423 in closed
# Processing Image - 424 in closed
# Processing Image - 425 in closed
# Processing Image - 426 in closed
# Processing Image - 427 in closed
# Processing Image - 428 in closed
# Processing Image - 429 in closed
# Processing Image - 430 in closed
# Processing Image - 431 in closed
# Processing Image - 432 in closed
# Processing Image - 433 in closed
# Processing Image - 434 in closed
# Processing Image - 435 in closed
# Processing Image - 436 in closed
# Processing Image - 437 in closed
# Processing Image - 438 in closed
# Processing Image - 439 in closed
# Processing Image - 440 in closed
# Processing Image - 441 in closed
# Processing Image - 442 in closed
# Processing Image - 443 in closed
# Processing Image - 444 in closed
# Processing Image - 445 in closed
# Processing Image - 446 in closed
# Processing Image - 447 in closed
# Processing Image - 448 in closed
# Processing Image - 449 in closed
# Processing Image - 450 in closed
# Processing Image - 451 in closed
# Processing Image - 452 in closed
# Processing Image - 453 in closed
# Processing Image - 454 in closed
# Processing Image - 455 in closed
# Processing Image - 456 in closed
# Processing Image - 457 in closed
# Processing Image - 458 in closed
# Processing Image - 459 in closed
# Processing Image - 460 in closed
# Processing Image - 461 in closed
# Processing Image - 462 in closed
# Processing Image - 463 in closed
# Processing Image - 464 in closed
# Processing Image - 465 in closed
# Processing Image - 466 in closed
# Processing Image - 467 in closed
# Processing Image - 468 in closed
# Processing Image - 469 in closed
# Processing Image - 470 in closed
# Processing Image - 471 in closed
# Processing Image - 472 in closed
# Processing Image - 473 in closed
# Processing Image - 474 in closed
# Processing Image - 475 in closed
# Processing Image - 476 in closed
# Processing Image - 477 in closed
# Processing Image - 478 in closed
# Processing Image - 479 in closed
# Processing Image - 480 in closed
# Processing Image - 481 in closed
# Processing Image - 482 in closed
# Processing Image - 483 in closed
# Processing Image - 484 in closed
# Processing Image - 485 in closed
# Processing Image - 486 in closed
# Processing Image - 487 in closed
# Processing Image - 488 in closed
# Processing Image - 489 in closed
# Processing Image - 490 in closed
# Processing Image - 491 in closed
# Processing Image - 492 in closed
# Processing Image - 493 in closed
# Processing Image - 494 in closed
# Processing Image - 495 in closed
# Processing Image - 496 in closed
# Processing Image - 497 in closed
# Processing Image - 498 in closed
# Processing Image - 499 in closed
# Processing Image - 500 in closed
# Processing Image - 501 in closed
# Processing Image - 502 in closed
# Processing Image - 503 in closed
# Processing Image - 504 in closed
# Processing Image - 505 in closed
# Processing Image - 506 in closed
# Processing Image - 507 in closed
# Processing Image - 508 in closed
# Processing Image - 509 in closed
# Processing Image - 510 in closed
# Processing Image - 511 in closed
# Processing Image - 512 in closed
# Processing Image - 513 in closed
# Processing Image - 514 in closed
# Processing Image - 515 in closed
# Processing Image - 516 in closed
# Processing Image - 517 in closed
# Processing Image - 518 in closed
# Processing Image - 519 in closed
# Processing Image - 520 in closed
# Processing Image - 521 in closed
# Processing Image - 522 in closed
# Processing Image - 523 in closed
# Processing Image - 524 in closed
# Processing Image - 525 in closed
# Processing Image - 526 in closed
# Processing Image - 527 in closed
# Processing Image - 528 in closed
# Processing Image - 529 in closed
# Processing Image - 530 in closed
# Processing Image - 531 in closed
# Processing Image - 532 in closed
# Processing Image - 533 in closed
# Processing Image - 534 in closed
# Processing Image - 535 in closed
# Processing Image - 536 in closed
# Processing Image - 537 in closed
# Processing Image - 538 in closed
# Processing Image - 539 in closed
# Processing Image - 540 in closed
# Processing Image - 541 in closed
# Processing Image - 542 in closed
# Processing Image - 543 in closed
# Processing Image - 544 in closed
# Processing Image - 545 in closed
# Processing Image - 546 in closed
# Processing Image - 547 in closed
# Processing Image - 548 in closed
# Processing Image - 549 in closed
# Processing Image - 550 in closed
# Processing Image - 551 in closed
# Processing Image - 552 in closed
# Processing Image - 553 in closed
# Processing Image - 554 in closed
# Processing Image - 555 in closed
# Processing Image - 556 in closed
# Processing Image - 557 in closed
# Processing Image - 558 in closed
# Processing Image - 559 in closed
# Processing Image - 560 in closed
# Processing Image - 561 in closed
# Processing Image - 562 in closed
# Processing Image - 563 in closed
# Processing Image - 564 in closed
# Processing Image - 565 in closed
# Processing Image - 566 in closed
# Processing Image - 567 in closed
# Processing Image - 568 in closed
# Processing Image - 569 in closed
# Processing Image - 570 in closed
# Processing Image - 571 in closed
# Processing Image - 572 in closed
# Processing Image - 573 in closed
# Processing Image - 574 in closed
# Processing Image - 575 in closed
# Processing Image - 576 in closed
# Processing Image - 577 in closed
# Processing Image - 578 in closed
# Processing Image - 579 in closed
# Processing Image - 580 in closed
# Processing Image - 581 in closed
# Processing Image - 582 in closed
# Processing Image - 583 in closed
# Processing Image - 584 in closed
# Processing Image - 585 in closed
# Processing Image - 586 in closed
# Processing Image - 587 in closed
# Processing Image - 588 in closed
# Processing Image - 589 in closed
# Processing Image - 590 in closed
# Processing Image - 591 in closed
# Processing Image - 592 in closed
# Processing Image - 593 in closed
# Processing Image - 594 in closed
# Processing Image - 595 in closed
# Processing Image - 596 in closed
# Processing Image - 597 in closed
# Processing Image - 598 in closed
# Processing Image - 599 in closed
# Processing Image - 600 in closed
# Processing Image - 601 in closed
# Processing Image - 602 in closed
# Processing Image - 603 in closed
# Processing Image - 604 in closed
# Processing Image - 605 in closed
# Processing Image - 606 in closed
# Processing Image - 607 in closed
# Processing Image - 608 in closed
# Processing Image - 609 in closed
# Processing Image - 610 in closed
# Processing Image - 611 in closed
# Processing Image - 612 in closed
# Processing Image - 613 in closed
# Processing Image - 614 in closed
# Processing Image - 615 in closed
# Processing Image - 616 in closed
# Processing Image - 617 in closed
# Processing Image - 618 in closed
# Processing Image - 619 in closed
# Processing Image - 620 in closed
# Processing Image - 621 in closed
# Processing Image - 622 in closed
# Processing Image - 623 in closed
# Processing Image - 624 in closed
# Processing Image - 625 in closed
# Processing Image - 626 in closed
# Processing Image - 627 in closed
# Processing Image - 628 in closed
# Processing Image - 629 in closed
# Processing Image - 630 in closed
# Processing Image - 631 in closed
# Processing Image - 632 in closed
# Processing Image - 633 in closed
# Processing Image - 634 in closed
# Processing Image - 635 in closed
# Processing Image - 636 in closed
# Processing Image - 637 in closed
# Processing Image - 638 in closed
# Processing Image - 639 in closed
# Processing Image - 640 in closed
# Processing Image - 641 in closed
# Processing Image - 642 in closed
# Processing Image - 643 in closed
# Processing Image - 644 in closed
# Processing Image - 645 in closed
# Processing Image - 646 in closed
# Processing Image - 647 in closed
# Processing Image - 648 in closed
# Processing Image - 649 in closed
# Processing Image - 650 in closed
# Processing Image - 651 in closed
# Processing Image - 652 in closed
# Processing Image - 653 in closed
# Processing Image - 654 in closed
# Processing Image - 655 in closed
# Processing Image - 656 in closed
# Processing Image - 657 in closed
# Processing Image - 658 in closed
# Processing Image - 659 in closed
# Processing Image - 660 in closed
# Processing Image - 661 in closed
# Processing Image - 662 in closed
# Processing Image - 663 in closed
# Processing Image - 664 in closed
# Processing Image - 665 in closed
# Processing Image - 666 in closed
# Processing Image - 667 in closed
# Processing Image - 668 in closed
# Processing Image - 669 in closed
# Processing Image - 670 in closed
# Processing Image - 671 in closed
# Processing Image - 672 in closed
# Processing Image - 673 in closed
# Processing Image - 674 in closed
# Processing Image - 675 in closed
# Processing Image - 676 in closed
# Processing Image - 677 in closed
# Processing Image - 678 in closed
# Processing Image - 679 in closed
# Processing Image - 680 in closed
# Processing Image - 681 in closed
# Processing Image - 682 in closed
# Processing Image - 683 in closed
# Processing Image - 684 in closed
# Processing Image - 685 in closed
# Processing Image - 686 in closed
# Processing Image - 687 in closed
# Processing Image - 688 in closed
# Processing Image - 689 in closed
# Processing Image - 690 in closed
# Processing Image - 691 in closed
# Processing Image - 692 in closed
# Processing Image - 693 in closed
# Processing Image - 694 in closed
# Processing Image - 695 in closed
# Processing Image - 696 in closed
# Processing Image - 697 in closed
# Processing Image - 698 in closed
# Processing Image - 699 in closed
# Processing Image - 700 in closed
# Processing Image - 701 in closed
# Processing Image - 702 in closed
# Processing Image - 703 in closed
# Processing Image - 704 in closed
# Processing Image - 705 in closed
# Processing Image - 706 in closed
# Processing Image - 707 in closed
# Processing Image - 708 in closed
# Processing Image - 709 in closed
# Processing Image - 710 in closed
# Processing Image - 711 in closed
# Processing Image - 712 in closed
# Processing Image - 713 in closed
# Processing Image - 714 in closed
# Processing Image - 715 in closed
# Processing Image - 716 in closed
# Processing Image - 717 in closed
# Processing Image - 718 in closed
# Processing Image - 719 in closed
# Processing Image - 720 in closed
# Processing Image - 721 in closed
# Processing Image - 722 in closed
# Processing Image - 723 in closed
# Processing Image - 724 in closed
# Processing Image - 725 in closed
# Processing Image - 726 in closed
# Processing Image - 727 in closed
# Processing Image - 728 in closed
# Processing Image - 729 in closed
# Processing Image - 730 in closed
# Processing Image - 731 in closed
# Processing Image - 732 in closed
# Processing Image - 733 in closed
# Processing Image - 734 in closed
# Processing Image - 735 in closed
# Processing Image - 736 in closed
# Processing Image - 737 in closed
# Processing Image - 738 in closed
# Processing Image - 739 in closed
# Processing Image - 740 in closed
# Processing Image - 741 in closed
# Processing Image - 742 in closed
# Processing Image - 743 in closed
# Processing Image - 744 in closed
# Processing Image - 745 in closed
# Processing Image - 746 in closed
# Processing Image - 747 in closed
# Processing Image - 748 in closed
# Processing Image - 749 in closed
# Processing Image - 750 in closed
# Processing Image - 751 in closed
# Processing Image - 752 in closed
# Processing Image - 753 in closed
# Processing Image - 754 in closed
# Processing Image - 755 in closed
# Processing Image - 756 in closed
# Processing Image - 757 in closed
# Processing Image - 758 in closed
# Processing Image - 759 in closed
# Processing Image - 760 in closed
# Processing Image - 761 in closed
# Processing Image - 762 in closed
# Processing Image - 763 in closed
# Processing Image - 764 in closed
# Processing Image - 765 in closed
# Processing Image - 766 in closed
# Processing Image - 767 in closed
# Processing Image - 768 in closed
# Processing Image - 769 in closed
# Processing Image - 770 in closed
# Processing Image - 771 in closed
# Processing Image - 772 in closed
# Processing Image - 773 in closed
# Processing Image - 774 in closed
# Processing Image - 775 in closed
# Processing Image - 776 in closed
# Processing Image - 777 in closed
# Processing Image - 778 in closed
# Processing Image - 779 in closed
# Processing Image - 780 in closed
# Processing Image - 781 in closed
# Processing Image - 782 in closed
# Processing Image - 783 in closed
# Processing Image - 784 in closed
# Processing Image - 785 in closed
# Processing Image - 786 in closed
# Processing Image - 787 in closed
# Processing Image - 788 in closed
# Processing Image - 789 in closed
# Processing Image - 790 in closed
# Processing Image - 791 in closed
# Processing Image - 792 in closed
# Processing Image - 793 in closed
# Processing Image - 794 in closed
# Processing Image - 795 in closed
# Processing Image - 796 in closed
# Processing Image - 797 in closed
# Processing Image - 798 in closed
# Processing Image - 799 in closed
# Processing Image - 800 in closed
# Processing Image - 801 in closed
# Processing Image - 802 in closed
# Processing Image - 803 in closed
# Processing Image - 804 in closed
# Processing Image - 805 in closed
# Processing Image - 806 in closed
# Processing Image - 807 in closed
# Processing Image - 808 in closed
# Processing Image - 809 in closed
# Processing Image - 810 in closed
# Processing Image - 811 in closed
# Processing Image - 812 in closed
# Processing Image - 813 in closed
# Processing Image - 814 in closed
# Processing Image - 815 in closed
# Processing Image - 816 in closed
# Processing Image - 817 in closed
# Processing Image - 818 in closed
# Processing Image - 819 in closed
# Processing Image - 820 in closed
# Processing Image - 821 in closed
# Processing Image - 822 in closed
# Processing Image - 823 in closed
# Processing Image - 824 in closed
# Processing Image - 825 in closed
# Processing Image - 826 in closed
# Processing Image - 827 in closed
# Processing Image - 828 in closed
# Processing Image - 829 in closed
# Processing Image - 830 in closed
# Processing Image - 831 in closed
# Processing Image - 832 in closed
# Processing Image - 833 in closed
# Processing Image - 834 in closed
# Processing Image - 835 in closed
# Processing Image - 836 in closed
# Processing Image - 837 in closed
# Processing Image - 838 in closed
# Processing Image - 839 in closed
# Processing Image - 840 in closed
# Processing Image - 841 in closed
# Processing Image - 842 in closed
# Processing Image - 843 in closed
# Processing Image - 844 in closed
# Processing Image - 845 in closed
# Processing Image - 846 in closed
# Processing Image - 847 in closed
# Processing Image - 848 in closed
# Processing Image - 849 in closed
# Processing Image - 850 in closed
# Processing Image - 851 in closed
# Processing Image - 852 in closed
# Processing Image - 853 in closed
# Processing Image - 854 in closed
# Processing Image - 855 in closed
# Processing Image - 856 in closed
# Processing Image - 857 in closed
# Processing Image - 858 in closed
# Processing Image - 859 in closed
# Processing Image - 860 in closed
# Processing Image - 861 in closed
# Processing Image - 862 in closed
# Processing Image - 863 in closed
# Processing Image - 864 in closed
# Processing Image - 865 in closed
# Processing Image - 866 in closed
# Processing Image - 867 in closed
# Processing Image - 868 in closed
# Processing Image - 869 in closed
# Processing Image - 870 in closed
# Processing Image - 871 in closed
# Processing Image - 872 in closed
# Processing Image - 873 in closed
# Processing Image - 874 in closed
# Processing Image - 875 in closed
# Processing Image - 876 in closed
# Processing Image - 877 in closed
# Processing Image - 878 in closed
# Processing Image - 879 in closed
# Processing Image - 880 in closed
# Processing Image - 881 in closed
# Processing Image - 882 in closed
# Processing Image - 883 in closed
# Processing Image - 884 in closed
# Processing Image - 885 in closed
# Processing Image - 886 in closed
# Processing Image - 887 in closed
# Processing Image - 888 in closed
# Processing Image - 889 in closed
# Processing Image - 890 in closed
# Processing Image - 891 in closed
# Processing Image - 892 in closed
# Processing Image - 893 in closed
# Processing Image - 894 in closed
# Processing Image - 895 in closed
# Processing Image - 896 in closed
# Processing Image - 897 in closed
# Processing Image - 898 in closed
# Processing Image - 899 in closed
# Processing Image - 900 in closed
# Processing Image - 901 in closed
# Processing Image - 902 in closed
# Processing Image - 903 in closed
# Processing Image - 904 in closed
# Processing Image - 905 in closed
# Processing Image - 906 in closed
# Processing Image - 907 in closed
# Processing Image - 908 in closed
# Processing Image - 909 in closed
# Processing Image - 910 in closed
# Processing Image - 911 in closed
# Processing Image - 912 in closed
# Processing Image - 913 in closed
# Processing Image - 914 in closed
# Processing Image - 915 in closed
# Processing Image - 916 in closed
# Processing Image - 917 in closed
# Processing Image - 918 in closed
# Processing Image - 919 in closed
# Processing Image - 920 in closed
# Processing Image - 921 in closed
# Processing Image - 922 in closed
# Processing Image - 923 in closed
# Processing Image - 924 in closed
# Processing Image - 925 in closed
# Processing Image - 926 in closed
# Processing Image - 927 in closed
# Processing Image - 928 in closed
# Processing Image - 929 in closed
# Processing Image - 930 in closed
# Processing Image - 931 in closed
# Processing Image - 932 in closed
# Processing Image - 933 in closed
# Processing Image - 934 in closed
# Processing Image - 935 in closed
# Processing Image - 936 in closed
# Processing Image - 937 in closed
# Processing Image - 938 in closed
# Processing Image - 939 in closed
# Processing Image - 940 in closed
# Processing Image - 941 in closed
# Processing Image - 942 in closed
# Processing Image - 943 in closed
# Processing Image - 944 in closed
# Processing Image - 945 in closed
# Processing Image - 946 in closed
# Processing Image - 947 in closed
# Processing Image - 948 in closed
# Processing Image - 949 in closed
# Processing Image - 950 in closed
# Processing Image - 951 in closed
# Processing Image - 952 in closed
# Processing Image - 953 in closed
# Processing Image - 954 in closed
# Processing Image - 955 in closed
# Processing Image - 956 in closed
# Processing Image - 957 in closed
# Processing Image - 958 in closed
# Processing Image - 959 in closed
# Processing Image - 960 in closed
# Processing Image - 961 in closed
# Processing Image - 962 in closed
# Processing Image - 963 in closed
# Processing Image - 964 in closed
# Processing Image - 965 in closed
# Processing Image - 966 in closed
# Processing Image - 967 in closed
# Processing Image - 968 in closed
# Processing Image - 969 in closed
# Processing Image - 970 in closed
# Processing Image - 971 in closed
# Processing Image - 972 in closed
# Processing Image - 973 in closed
# Processing Image - 974 in closed
# Processing Image - 975 in closed
# Processing Image - 976 in closed
# Processing Image - 977 in closed
# Processing Image - 978 in closed
# Processing Image - 979 in closed
# Processing Image - 980 in closed
# Processing Image - 981 in closed
# Processing Image - 982 in closed
# Processing Image - 983 in closed
# Processing Image - 984 in closed
# Processing Image - 985 in closed
# Processing Image - 986 in closed
# Processing Image - 987 in closed
# Processing Image - 988 in closed
# Processing Image - 989 in closed
# Processing Image - 990 in closed
# Processing Image - 991 in closed
# Processing Image - 992 in closed
# Processing Image - 993 in closed
# Processing Image - 994 in closed
# Processing Image - 995 in closed
# Processing Image - 996 in closed
# Processing Image - 997 in closed
# Processing Image - 998 in closed
# Processing Image - 999 in closed
# Processing Image - 1000 in closed
# Processing Image - 1001 in closed
# Processing Image - 1002 in closed
# Processing Image - 1003 in closed
# Processing Image - 1004 in closed
# Processing Image - 1005 in closed
# Processing Image - 1006 in closed
# Processing Image - 1007 in closed
# Processing Image - 1008 in closed
# Processing Image - 1009 in closed
# Processing Image - 1010 in closed
# Processing Image - 1011 in closed
# Processing Image - 1012 in closed
# Processing Image - 1013 in closed
# Processing Image - 1014 in closed
# Processing Image - 1015 in closed
# Processing Image - 1016 in closed
# Processing Image - 1017 in closed
# Processing Image - 1018 in closed
# Processing Image - 1019 in closed
# Processing Image - 1020 in closed
# Processing Image - 1021 in closed
# Processing Image - 1022 in closed
# Processing Image - 1023 in closed
# Processing Image - 1024 in closed
# Processing Image - 1025 in closed
# Processing Image - 1026 in closed
# Processing Image - 1027 in closed
# Processing Image - 1028 in closed
# Processing Image - 1029 in closed
# Processing Image - 1030 in closed
# Processing Image - 1031 in closed
# Processing Image - 1032 in closed
# Processing Image - 1033 in closed
# Processing Image - 1034 in closed
# Processing Image - 1035 in closed
# Processing Image - 1036 in closed
# Processing Image - 1037 in closed
# Processing Image - 1038 in closed
# Processing Image - 1039 in closed
# Processing Image - 1040 in closed
# Processing Image - 1041 in closed
# Processing Image - 1042 in closed
# Processing Image - 1043 in closed
# Processing Image - 1044 in closed
# Processing Image - 1045 in closed
# Processing Image - 1046 in closed
# Processing Image - 1047 in closed
# Processing Image - 1048 in closed
# Processing Image - 1049 in closed
# Processing Image - 1050 in closed
# Processing Image - 1051 in closed
# Processing Image - 1052 in closed
# Processing Image - 1053 in closed
# Processing Image - 1054 in closed
# Processing Image - 1055 in closed
# Processing Image - 1056 in closed
# Processing Image - 1057 in closed
# Processing Image - 1058 in closed
# Processing Image - 1059 in closed
# Processing Image - 1060 in closed
# Processing Image - 1061 in closed
# Processing Image - 1062 in closed
# Processing Image - 1063 in closed
# Processing Image - 1064 in closed
# Processing Image - 1065 in closed
# Processing Image - 1066 in closed
# Processing Image - 1067 in closed
# Processing Image - 1068 in closed
# Processing Image - 1069 in closed
# Processing Image - 1070 in closed
# Processing Image - 1071 in closed
# Processing Image - 1072 in closed
# Processing Image - 1073 in closed
# Processing Image - 1074 in closed
# Processing Image - 1075 in closed
# Processing Image - 1076 in closed
# Processing Image - 1077 in closed
# Processing Image - 1078 in closed
# Processing Image - 1079 in closed
# Processing Image - 1080 in closed
# Processing Image - 1081 in closed
# Processing Image - 1082 in closed
# Processing Image - 1083 in closed
# Processing Image - 1084 in closed
# Processing Image - 1085 in closed
# Processing Image - 1086 in closed
# Processing Image - 1087 in closed
# Processing Image - 1088 in closed
# Processing Image - 1089 in closed
# Processing Image - 1090 in closed
# Processing Image - 1091 in closed
# Processing Image - 1092 in closed
# Processing Image - 1093 in closed
# Processing Image - 1094 in closed
# Processing Image - 1095 in closed
# Processing Image - 1096 in closed
# Processing Image - 1097 in closed
# Processing Image - 1098 in closed
# Processing Image - 1099 in closed
# Processing Image - 1100 in closed
# Processing Image - 1101 in closed
# Processing Image - 1102 in closed
# Processing Image - 1103 in closed
# Processing Image - 1104 in closed
# Processing Image - 1105 in closed
# Processing Image - 1106 in closed
# Processing Image - 1107 in closed
# Processing Image - 1108 in closed
# Processing Image - 1109 in closed
# Processing Image - 1110 in closed
# Processing Image - 1111 in closed
# Processing Image - 1112 in closed
# Processing Image - 1113 in closed
# Processing Image - 1114 in closed
# Processing Image - 1115 in closed
# Processing Image - 1116 in closed
# Processing Image - 1117 in closed
# Processing Image - 1118 in closed
# Processing Image - 1119 in closed
# Processing Image - 1120 in closed
# Processing Image - 1121 in closed
# Processing Image - 1122 in closed
# Processing Image - 1123 in closed
# Processing Image - 1124 in closed
# Processing Image - 1125 in closed
# Processing Image - 1126 in closed
# Processing Image - 1127 in closed
# Processing Image - 1128 in closed
# Processing Image - 1129 in closed
# Processing Image - 1130 in closed
# Processing Image - 1131 in closed
# Processing Image - 1132 in closed
# Processing Image - 1133 in closed
# Processing Image - 1134 in closed
# Processing Image - 1135 in closed
# Processing Image - 1136 in closed
# Processing Image - 1137 in closed
# Processing Image - 1138 in closed
# Processing Image - 1139 in closed
# Processing Image - 1140 in closed
# Processing Image - 1141 in closed
# Processing Image - 1142 in closed
# Processing Image - 1143 in closed
# Processing Image - 1144 in closed
# Processing Image - 1145 in closed
# Processing Image - 1146 in closed
# Processing Image - 1147 in closed
# Processing Image - 1148 in closed
# Processing Image - 1149 in closed
# Processing Image - 1150 in closed
# Processing Image - 1151 in closed
# Processing Image - 1152 in closed
# Processing Image - 1153 in closed
# Processing Image - 1154 in closed
# Processing Image - 1155 in closed
# Processing Image - 1156 in closed
# Processing Image - 1157 in closed
# Processing Image - 1158 in closed
# Processing Image - 1159 in closed
# Processing Image - 1160 in closed
# Processing Image - 1161 in closed
# Processing Image - 1162 in closed
# Processing Image - 1163 in closed
# Processing Image - 1164 in closed
# Processing Image - 1165 in closed
# Processing Image - 1166 in closed
# Processing Image - 1167 in closed
# Processing Image - 1168 in closed
# Processing Image - 1169 in closed
# Processing Image - 1170 in closed
# Processing Image - 1171 in closed
# Processing Image - 1172 in closed
# Processing Image - 1173 in closed
# Processing Image - 1174 in closed
# Processing Image - 1175 in closed
# Processing Image - 1176 in closed
# Processing Image - 1177 in closed
# Processing Image - 1178 in closed
# Processing Image - 1179 in closed
# Processing Image - 1180 in closed
# Processing Image - 1181 in closed
# Processing Image - 1182 in closed
# Processing Image - 1183 in closed
# Processing Image - 1184 in closed
# Processing Image - 1185 in closed
# Processing Image - 1186 in closed
# Processing Image - 1187 in closed
# Processing Image - 1188 in closed
# Processing Image - 1189 in closed
# Processing Image - 1190 in closed
# Processing Image - 1191 in closed
# Processing Image - 1192 in closed
# Processing Image - 1 in open
# Processing Image - 2 in open
# Processing Image - 3 in open
# Processing Image - 4 in open
# Processing Image - 5 in open
# Processing Image - 6 in open
# Processing Image - 7 in open
# Processing Image - 8 in open
# Processing Image - 9 in open
# Processing Image - 10 in open
# Processing Image - 11 in open
# Processing Image - 12 in open
# Processing Image - 13 in open
# Processing Image - 14 in open
# Processing Image - 15 in open
# Processing Image - 16 in open
# Processing Image - 17 in open
# Processing Image - 18 in open
# Processing Image - 19 in open
# Processing Image - 20 in open
# Processing Image - 21 in open
# Processing Image - 22 in open
# Processing Image - 23 in open
# Processing Image - 24 in open
# Processing Image - 25 in open
# Processing Image - 26 in open
# Processing Image - 27 in open
# Processing Image - 28 in open
# Processing Image - 29 in open
# Processing Image - 30 in open
# Processing Image - 31 in open
# Processing Image - 32 in open
# Processing Image - 33 in open
# Processing Image - 34 in open
# Processing Image - 35 in open
# Processing Image - 36 in open
# Processing Image - 37 in open
# Processing Image - 38 in open
# Processing Image - 39 in open
# Processing Image - 40 in open
# Processing Image - 41 in open
# Processing Image - 42 in open
# Processing Image - 43 in open
# Processing Image - 44 in open
# Processing Image - 45 in open
# Processing Image - 46 in open
# Processing Image - 47 in open
# Processing Image - 48 in open
# Processing Image - 49 in open
# Processing Image - 50 in open
# Processing Image - 51 in open
# Processing Image - 52 in open
# Processing Image - 53 in open
# Processing Image - 54 in open
# Processing Image - 55 in open
# Processing Image - 56 in open
# Processing Image - 57 in open
# Processing Image - 58 in open
# Processing Image - 59 in open
# Processing Image - 60 in open
# Processing Image - 61 in open
# Processing Image - 62 in open
# Processing Image - 63 in open
# Processing Image - 64 in open
# Processing Image - 65 in open
# Processing Image - 66 in open
# Processing Image - 67 in open
# Processing Image - 68 in open
# Processing Image - 69 in open
# Processing Image - 70 in open
# Processing Image - 71 in open
# Processing Image - 72 in open
# Processing Image - 73 in open
# Processing Image - 74 in open
# Processing Image - 75 in open
# Processing Image - 76 in open
# Processing Image - 77 in open
# Processing Image - 78 in open
# Processing Image - 79 in open
# Processing Image - 80 in open
# Processing Image - 81 in open
# Processing Image - 82 in open
# Processing Image - 83 in open
# Processing Image - 84 in open
# Processing Image - 85 in open
# Processing Image - 86 in open
# Processing Image - 87 in open
# Processing Image - 88 in open
# Processing Image - 89 in open
# Processing Image - 90 in open
# Processing Image - 91 in open
# Processing Image - 92 in open
# Processing Image - 93 in open
# Processing Image - 94 in open
# Processing Image - 95 in open
# Processing Image - 96 in open
# Processing Image - 97 in open
# Processing Image - 98 in open
# Processing Image - 99 in open
# Processing Image - 100 in open
# Processing Image - 101 in open
# Processing Image - 102 in open
# Processing Image - 103 in open
# Processing Image - 104 in open
# Processing Image - 105 in open
# Processing Image - 106 in open
# Processing Image - 107 in open
# Processing Image - 108 in open
# Processing Image - 109 in open
# Processing Image - 110 in open
# Processing Image - 111 in open
# Processing Image - 112 in open
# Processing Image - 113 in open
# Processing Image - 114 in open
# Processing Image - 115 in open
# Processing Image - 116 in open
# Processing Image - 117 in open
# Processing Image - 118 in open
# Processing Image - 119 in open
# Processing Image - 120 in open
# Processing Image - 121 in open
# Processing Image - 122 in open
# Processing Image - 123 in open
# Processing Image - 124 in open
# Processing Image - 125 in open
# Processing Image - 126 in open
# Processing Image - 127 in open
# Processing Image - 128 in open
# Processing Image - 129 in open
# Processing Image - 130 in open
# Processing Image - 131 in open
# Processing Image - 132 in open
# Processing Image - 133 in open
# Processing Image - 134 in open
# Processing Image - 135 in open
# Processing Image - 136 in open
# Processing Image - 137 in open
# Processing Image - 138 in open
# Processing Image - 139 in open
# Processing Image - 140 in open
# Processing Image - 141 in open
# Processing Image - 142 in open
# Processing Image - 143 in open
# Processing Image - 144 in open
# Processing Image - 145 in open
# Processing Image - 146 in open
# Processing Image - 147 in open
# Processing Image - 148 in open
# Processing Image - 149 in open
# Processing Image - 150 in open
# Processing Image - 151 in open
# Processing Image - 152 in open
# Processing Image - 153 in open
# Processing Image - 154 in open
# Processing Image - 155 in open
# Processing Image - 156 in open
# Processing Image - 157 in open
# Processing Image - 158 in open
# Processing Image - 159 in open
# Processing Image - 160 in open
# Processing Image - 161 in open
# Processing Image - 162 in open
# Processing Image - 163 in open
# Processing Image - 164 in open
# Processing Image - 165 in open
# Processing Image - 166 in open
# Processing Image - 167 in open
# Processing Image - 168 in open
# Processing Image - 169 in open
# Processing Image - 170 in open
# Processing Image - 171 in open
# Processing Image - 172 in open
# Processing Image - 173 in open
# Processing Image - 174 in open
# Processing Image - 175 in open
# Processing Image - 176 in open
# Processing Image - 177 in open
# Processing Image - 178 in open
# Processing Image - 179 in open
# Processing Image - 180 in open
# Processing Image - 181 in open
# Processing Image - 182 in open
# Processing Image - 183 in open
# Processing Image - 184 in open
# Processing Image - 185 in open
# Processing Image - 186 in open
# Processing Image - 187 in open
# Processing Image - 188 in open
# Processing Image - 189 in open
# Processing Image - 190 in open
# Processing Image - 191 in open
# Processing Image - 192 in open
# Processing Image - 193 in open
# Processing Image - 194 in open
# Processing Image - 195 in open
# Processing Image - 196 in open
# Processing Image - 197 in open
# Processing Image - 198 in open
# Processing Image - 199 in open
# Processing Image - 200 in open
# Processing Image - 201 in open
# Processing Image - 202 in open
# Processing Image - 203 in open
# Processing Image - 204 in open
# Processing Image - 205 in open
# Processing Image - 206 in open
# Processing Image - 207 in open
# Processing Image - 208 in open
# Processing Image - 209 in open
# Processing Image - 210 in open
# Processing Image - 211 in open
# Processing Image - 212 in open
# Processing Image - 213 in open
# Processing Image - 214 in open
# Processing Image - 215 in open
# Processing Image - 216 in open
# Processing Image - 217 in open
# Processing Image - 218 in open
# Processing Image - 219 in open
# Processing Image - 220 in open
# Processing Image - 221 in open
# Processing Image - 222 in open
# Processing Image - 223 in open
# Processing Image - 224 in open
# Processing Image - 225 in open
# Processing Image - 226 in open
# Processing Image - 227 in open
# Processing Image - 228 in open
# Processing Image - 229 in open
# Processing Image - 230 in open
# Processing Image - 231 in open
# Processing Image - 232 in open
# Processing Image - 233 in open
# Processing Image - 234 in open
# Processing Image - 235 in open
# Processing Image - 236 in open
# Processing Image - 237 in open
# Processing Image - 238 in open
# Processing Image - 239 in open
# Processing Image - 240 in open
# Processing Image - 241 in open
# Processing Image - 242 in open
# Processing Image - 243 in open
# Processing Image - 244 in open
# Processing Image - 245 in open
# Processing Image - 246 in open
# Processing Image - 247 in open
# Processing Image - 248 in open
# Processing Image - 249 in open
# Processing Image - 250 in open
# Processing Image - 251 in open
# Processing Image - 252 in open
# Processing Image - 253 in open
# Processing Image - 254 in open
# Processing Image - 255 in open
# Processing Image - 256 in open
# Processing Image - 257 in open
# Processing Image - 258 in open
# Processing Image - 259 in open
# Processing Image - 260 in open
# Processing Image - 261 in open
# Processing Image - 262 in open
# Processing Image - 263 in open
# Processing Image - 264 in open
# Processing Image - 265 in open
# Processing Image - 266 in open
# Processing Image - 267 in open
# Processing Image - 268 in open
# Processing Image - 269 in open
# Processing Image - 270 in open
# Processing Image - 271 in open
# Processing Image - 272 in open
# Processing Image - 273 in open
# Processing Image - 274 in open
# Processing Image - 275 in open
# Processing Image - 276 in open
# Processing Image - 277 in open
# Processing Image - 278 in open
# ...
# Processing Image - 723 in open
# Processing Image - 724 in open
# Processing Image - 725 in open
# Processing Image - 726 in open
# Processing Image - 727 in open
# Processing Image - 728 in open
# Processing Image - 729 in open
# Processing Image - 730 in open
# Processing Image - 731 in open
# Processing Image - 732 in open
# Processing Image - 733 in open
# Processing Image - 734 in open
# Processing Image - 735 in open
# Processing Image - 736 in open
# Processing Image - 737 in open
# Processing Image - 738 in open
# Processing Image - 739 in open
# Processing Image - 740 in open
# Processing Image - 741 in open
# Processing Image - 742 in open
# Processing Image - 743 in open
# Processing Image - 744 in open
# Processing Image - 745 in open
# Processing Image - 746 in open
# Processing Image - 747 in open
# Processing Image - 748 in open
# Processing Image - 749 in open
# Processing Image - 750 in open
# Processing Image - 751 in open
# Processing Image - 752 in open
# Processing Image - 753 in open
# Processing Image - 754 in open
# Processing Image - 755 in open
# Processing Image - 756 in open
# Processing Image - 757 in open
# Processing Image - 758 in open
# Processing Image - 759 in open
# Processing Image - 760 in open
# Processing Image - 761 in open
# Processing Image - 762 in open
# Processing Image - 763 in open
# Processing Image - 764 in open
# Processing Image - 765 in open
# Processing Image - 766 in open
# Processing Image - 767 in open
# Processing Image - 768 in open
# Processing Image - 769 in open
# Processing Image - 770 in open
# Processing Image - 771 in open
# Processing Image - 772 in open
# Processing Image - 773 in open
# Processing Image - 774 in open
# Processing Image - 775 in open
# Processing Image - 776 in open
# Processing Image - 777 in open
# Processing Image - 778 in open
# Processing Image - 779 in open
# Processing Image - 780 in open
# Processing Image - 781 in open
# Processing Image - 782 in open
# Processing Image - 783 in open
# Processing Image - 784 in open
# Processing Image - 785 in open
# Processing Image - 786 in open
# Processing Image - 787 in open
# Processing Image - 788 in open
# Processing Image - 789 in open
# Processing Image - 790 in open
# Processing Image - 791 in open
# Processing Image - 792 in open
# Processing Image - 793 in open
# Processing Image - 794 in open
# Processing Image - 795 in open
# Processing Image - 796 in open
# Processing Image - 797 in open
# Processing Image - 798 in open
# Processing Image - 799 in open
# Processing Image - 800 in open
# Processing Image - 801 in open
# Processing Image - 802 in open
# Processing Image - 803 in open
# Processing Image - 804 in open
# Processing Image - 805 in open
# Processing Image - 806 in open
# Processing Image - 807 in open
# Processing Image - 808 in open
# Processing Image - 809 in open
# Processing Image - 810 in open
# Processing Image - 811 in open
# Processing Image - 812 in open
# Processing Image - 813 in open
# Processing Image - 814 in open
# Processing Image - 815 in open
# Processing Image - 816 in open
# Processing Image - 817 in open
# Processing Image - 818 in open
# Processing Image - 819 in open
# Processing Image - 820 in open
# Processing Image - 821 in open
# Processing Image - 822 in open
# Processing Image - 823 in open
# Processing Image - 824 in open
# Processing Image - 825 in open
# Processing Image - 826 in open
# Processing Image - 827 in open
# Processing Image - 828 in open
# Processing Image - 829 in open
# Processing Image - 830 in open
# Processing Image - 831 in open
# Processing Image - 832 in open
# Processing Image - 833 in open
# Processing Image - 834 in open
# Processing Image - 835 in open
# Processing Image - 836 in open
# Processing Image - 837 in open
# Processing Image - 838 in open
# Processing Image - 839 in open
# Processing Image - 840 in open
# Processing Image - 841 in open
# Processing Image - 842 in open
# Processing Image - 843 in open
# Processing Image - 844 in open
# Processing Image - 845 in open
# Processing Image - 846 in open
# Processing Image - 847 in open
# Processing Image - 848 in open
# Processing Image - 849 in open
# Processing Image - 850 in open
# Processing Image - 851 in open
# Processing Image - 852 in open
# Processing Image - 853 in open
# Processing Image - 854 in open
# Processing Image - 855 in open
# Processing Image - 856 in open
# Processing Image - 857 in open
# Processing Image - 858 in open
# Processing Image - 859 in open
# Processing Image - 860 in open
# Processing Image - 861 in open
# Processing Image - 862 in open
# Processing Image - 863 in open
# Processing Image - 864 in open
# Processing Image - 865 in open
# Processing Image - 866 in open
# Processing Image - 867 in open
# Processing Image - 868 in open
# Processing Image - 869 in open
# Processing Image - 870 in open
# Processing Image - 871 in open
# Processing Image - 872 in open
# Processing Image - 873 in open
# Processing Image - 874 in open
# Processing Image - 875 in open
# Processing Image - 876 in open
# Processing Image - 877 in open
# Processing Image - 878 in open
# Processing Image - 879 in open
# Processing Image - 880 in open
# Processing Image - 881 in open
# Processing Image - 882 in open
# Processing Image - 883 in open
# Processing Image - 884 in open
# Processing Image - 885 in open
# Processing Image - 886 in open
# Processing Image - 887 in open
# Processing Image - 888 in open
# Processing Image - 889 in open
# Processing Image - 890 in open
# Processing Image - 891 in open
# Processing Image - 892 in open
# Processing Image - 893 in open
# Processing Image - 894 in open
# Processing Image - 895 in open
# Processing Image - 896 in open
# Processing Image - 897 in open
# Processing Image - 898 in open
# Processing Image - 899 in open
# Processing Image - 900 in open
# Processing Image - 901 in open
# Processing Image - 902 in open
# Processing Image - 903 in open
# Processing Image - 904 in open
# Processing Image - 905 in open
# Processing Image - 906 in open
# Processing Image - 907 in open
# Processing Image - 908 in open
# Processing Image - 909 in open
# Processing Image - 910 in open
# Processing Image - 911 in open
# Processing Image - 912 in open
# Processing Image - 913 in open
# Processing Image - 914 in open
# Processing Image - 915 in open
# Processing Image - 916 in open
# Processing Image - 917 in open
# Processing Image - 918 in open
# Processing Image - 919 in open
# Processing Image - 920 in open
# Processing Image - 921 in open
# Processing Image - 922 in open
# Processing Image - 923 in open
# Processing Image - 924 in open
# Processing Image - 925 in open
# Processing Image - 926 in open
# Processing Image - 927 in open
# Processing Image - 928 in open
# Processing Image - 929 in open
# Processing Image - 930 in open
# Processing Image - 931 in open
# Processing Image - 932 in open
# Processing Image - 933 in open
# Processing Image - 934 in open
# Processing Image - 935 in open
# Processing Image - 936 in open
# Processing Image - 937 in open
# Processing Image - 938 in open
# Processing Image - 939 in open
# Processing Image - 940 in open
# Processing Image - 941 in open
# Processing Image - 942 in open
# Processing Image - 943 in open
# Processing Image - 944 in open
# Processing Image - 945 in open
# Processing Image - 946 in open
# Processing Image - 947 in open
# Processing Image - 948 in open
# Processing Image - 949 in open
# Processing Image - 950 in open
# Processing Image - 951 in open
# Processing Image - 952 in open
# Processing Image - 953 in open
# Processing Image - 954 in open
# Processing Image - 955 in open
# Processing Image - 956 in open
# Processing Image - 957 in open
# Processing Image - 958 in open
# Processing Image - 959 in open
# Processing Image - 960 in open
# Processing Image - 961 in open
# Processing Image - 962 in open
# Processing Image - 963 in open
# Processing Image - 964 in open
# Processing Image - 965 in open
# Processing Image - 966 in open
# Processing Image - 967 in open
# Processing Image - 968 in open
# Processing Image - 969 in open
# Processing Image - 970 in open
# Processing Image - 971 in open
# Processing Image - 972 in open
# Processing Image - 973 in open
# Processing Image - 974 in open
# Processing Image - 975 in open
# Processing Image - 976 in open
# Processing Image - 977 in open
# Processing Image - 978 in open
# Processing Image - 979 in open
# Processing Image - 980 in open
# Processing Image - 981 in open
# Processing Image - 982 in open
# Processing Image - 983 in open
# Processing Image - 984 in open
# Processing Image - 985 in open
# Processing Image - 986 in open
# Processing Image - 987 in open
# Processing Image - 988 in open
# Processing Image - 989 in open
# Processing Image - 990 in open
# Processing Image - 991 in open
# Processing Image - 992 in open
# Processing Image - 993 in open
# Processing Image - 994 in open
# Processing Image - 995 in open
# Processing Image - 996 in open
# Processing Image - 997 in open
# Processing Image - 998 in open
# Processing Image - 999 in open
# Processing Image - 1000 in open
# Processing Image - 1001 in open
# Processing Image - 1002 in open
# Processing Image - 1003 in open
# Processing Image - 1004 in open
# Processing Image - 1005 in open
# Processing Image - 1006 in open
# Processing Image - 1007 in open
# Processing Image - 1008 in open
# Processing Image - 1009 in open
# Processing Image - 1010 in open
# Processing Image - 1011 in open
# Processing Image - 1012 in open
# Processing Image - 1013 in open
# Processing Image - 1014 in open
# Processing Image - 1015 in open
# Processing Image - 1016 in open
# Processing Image - 1017 in open
# Processing Image - 1018 in open
# Processing Image - 1019 in open
# Processing Image - 1020 in open
# Processing Image - 1021 in open
# Processing Image - 1022 in open
# Processing Image - 1023 in open
# Processing Image - 1024 in open
# Processing Image - 1025 in open
# Processing Image - 1026 in open
# Processing Image - 1027 in open
# Processing Image - 1028 in open
# Processing Image - 1029 in open
# Processing Image - 1030 in open
# Processing Image - 1031 in open
# Processing Image - 1032 in open
# Processing Image - 1033 in open
# Processing Image - 1034 in open
# Processing Image - 1035 in open
# Processing Image - 1036 in open
# Processing Image - 1037 in open
# Processing Image - 1038 in open
# Processing Image - 1039 in open
# Processing Image - 1040 in open
# Processing Image - 1041 in open
# Processing Image - 1042 in open
# Processing Image - 1043 in open
# Processing Image - 1044 in open
# Processing Image - 1045 in open
# Processing Image - 1046 in open
# Processing Image - 1047 in open
# Processing Image - 1048 in open
# Processing Image - 1049 in open
# Processing Image - 1050 in open
# Processing Image - 1051 in open
# Processing Image - 1052 in open
# Processing Image - 1053 in open
# Processing Image - 1054 in open
# Processing Image - 1055 in open
# Processing Image - 1056 in open
# Processing Image - 1057 in open
# Processing Image - 1058 in open
# Processing Image - 1059 in open
# Processing Image - 1060 in open
# Processing Image - 1061 in open
# Processing Image - 1062 in open
# Processing Image - 1063 in open
# Processing Image - 1064 in open
# Processing Image - 1065 in open
# Processing Image - 1066 in open
# Processing Image - 1067 in open
# Processing Image - 1068 in open
# Processing Image - 1069 in open
# Processing Image - 1070 in open
# Processing Image - 1071 in open
# Processing Image - 1072 in open
# Processing Image - 1073 in open
# Processing Image - 1074 in open
# Processing Image - 1075 in open
# Processing Image - 1076 in open
# Processing Image - 1077 in open
# Processing Image - 1078 in open
# Processing Image - 1079 in open
# Processing Image - 1080 in open
# Processing Image - 1081 in open
# Processing Image - 1082 in open
# Processing Image - 1083 in open
# Processing Image - 1084 in open
# Processing Image - 1085 in open
# Processing Image - 1086 in open
# Processing Image - 1087 in open
# Processing Image - 1088 in open
# Processing Image - 1089 in open
# Processing Image - 1090 in open
# Processing Image - 1091 in open
# Processing Image - 1092 in open
# Processing Image - 1093 in open
# Processing Image - 1094 in open
# Processing Image - 1095 in open
# Processing Image - 1096 in open
# Processing Image - 1097 in open
# Processing Image - 1098 in open
# Processing Image - 1099 in open
# Processing Image - 1100 in open
# Processing Image - 1101 in open
# Processing Image - 1102 in open
# Processing Image - 1103 in open
# Processing Image - 1104 in open
# Processing Image - 1105 in open
# Processing Image - 1106 in open
# Processing Image - 1107 in open
# Processing Image - 1108 in open
# Processing Image - 1109 in open
# Processing Image - 1110 in open
# Processing Image - 1111 in open
# Processing Image - 1112 in open
# Processing Image - 1113 in open
# Processing Image - 1114 in open
# Processing Image - 1115 in open
# Processing Image - 1116 in open
# Processing Image - 1117 in open
# Processing Image - 1118 in open
# Processing Image - 1119 in open
# Processing Image - 1120 in open
# Processing Image - 1121 in open
# Processing Image - 1122 in open
# Processing Image - 1123 in open
# Processing Image - 1124 in open
# Processing Image - 1125 in open
# Processing Image - 1126 in open
# Processing Image - 1127 in open
# Processing Image - 1128 in open
# Processing Image - 1129 in open
# Processing Image - 1130 in open
# Processing Image - 1131 in open
# Processing Image - 1132 in open
# Processing Image - 1133 in open
# Processing Image - 1134 in open
# Processing Image - 1135 in open
# Processing Image - 1136 in open
# Processing Image - 1137 in open
# Processing Image - 1138 in open
# Processing Image - 1139 in open
# Processing Image - 1140 in open
# Processing Image - 1141 in open
# Processing Image - 1142 in open
# Processing Image - 1143 in open
# Processing Image - 1144 in open
# Processing Image - 1145 in open
# Processing Image - 1146 in open
# Processing Image - 1147 in open
# Processing Image - 1148 in open
# Processing Image - 1149 in open
# Processing Image - 1150 in open
# Processing Image - 1151 in open
# Processing Image - 1152 in open
# Processing Image - 1153 in open
# Processing Image - 1154 in open
# Processing Image - 1155 in open
# Processing Image - 1156 in open
# Processing Image - 1157 in open
# Processing Image - 1158 in open
# Processing Image - 1159 in open
# Processing Image - 1160 in open
# Processing Image - 1161 in open
# Processing Image - 1162 in open
# Processing Image - 1163 in open
# Processing Image - 1164 in open
# Processing Image - 1165 in open
# Processing Image - 1166 in open
# Processing Image - 1167 in open
# Processing Image - 1168 in open
# Processing Image - 1169 in open
# Processing Image - 1170 in open
# Processing Image - 1171 in open
# Processing Image - 1172 in open
# Processing Image - 1173 in open
# Processing Image - 1174 in open
# Processing Image - 1175 in open
# Processing Image - 1176 in open
# Processing Image - 1177 in open
# Processing Image - 1178 in open
# Processing Image - 1179 in open
# Processing Image - 1180 in open
# Processing Image - 1181 in open
# Processing Image - 1182 in open
# Processing Image - 1183 in open
# Processing Image - 1184 in open
# Processing Image - 1185 in open
# Processing Image - 1186 in open
# Processing Image - 1187 in open
# Processing Image - 1188 in open
# Processing Image - 1189 in open
# Processing Image - 1190 in open
# Processing Image - 1191 in open
# Processing Image - 1192 in open
# Processing Image - 1193 in open
# Processing Image - 1194 in open
# Processing Image - 1195 in open
# Processing Image - 1196 in open
# Processing Image - 1197 in open
# Processing Image - 1198 in open
# Processing Image - 1199 in open
# Processing Image - 1200 in open
# Processing Image - 1201 in open
# Processing Image - 1202 in open
# Processing Image - 1203 in open
# Processing Image - 1204 in open
# Processing Image - 1205 in open
# Processing Image - 1206 in open
# Processing Image - 1207 in open
# Processing Image - 1208 in open
# Processing Image - 1209 in open
# Processing Image - 1210 in open
# Processing Image - 1211 in open
# Processing Image - 1212 in open
# Processing Image - 1213 in open
# Processing Image - 1214 in open
# Processing Image - 1215 in open
# Processing Image - 1216 in open
# Processing Image - 1217 in open
# Processing Image - 1218 in open
# Processing Image - 1219 in open
# Processing Image - 1220 in open
# Processing Image - 1221 in open
# Processing Image - 1222 in open
# Processing Image - 1223 in open
# Processing Image - 1224 in open
# Processing Image - 1225 in open
# Processing Image - 1226 in open
# Processing Image - 1227 in open
# Processing Image - 1228 in open
# Processing Image - 1229 in open
# Processing Image - 1230 in open

# %%
print("[STATUS] color feature vector size {}".format(np.array(color_features).shape))
# Out:
# [STATUS] color feature vector size (2422, 512)

# %%
# get the overall feature vector size
print("[STATUS] color feature vector size {}".format(np.array(color_features).shape))
# Out:
# [STATUS] color feature vector size (2422, 512)

# %%
# get the overall training label size
print("[STATUS] training Labels {}".format(np.array(color_features_labels).shape))
# Out:
# [STATUS] training Labels (2422,)

# %%
# encode the target labels
def replace(my_list, my_dict):
    return [x if x not in my_dict else my_dict[x] for x in my_list]

labels_dict = {'closed': 0,'open': 1,}
target = replace(color_features_labels, labels_dict)

print("[STATUS] training labels encoded...")
# Out:
# [STATUS] training labels encoded...

# %%
# scale features in the range (0-1)
scaler            = MinMaxScaler(feature_range=(0, 1))
rescaled_features = scaler.fit_transform(color_features)
print("[STATUS] feature vector normalized...")
print("[STATUS] target labels: {}".format(np.array(target)))
print("[STATUS] target labels shape: {}".format(np.array(target).shape))
# Out:
# [STATUS] feature vector normalized...
# [STATUS] target labels: [0 0 0 ... 1 1 1]
# [STATUS] target labels shape: (2422,)

# %%
# save the feature vector using HDF5
h5f_data = h5py.File('/content/drive/MyDrive/HOG/histogramaDataset.h5', 'w')
h5f_data.create_dataset('ojosCaracteristicas', data=np.array(rescaled_features))

h5f_label = h5py.File('/content/drive/MyDrive/HOG/histogramaDatasetlabels.h5', 'w')
h5f_label.create_dataset('ojosCaracteristicas_Etiquetas', data=np.array(target))

h5f_data.close()
h5f_label.close()

print("[STATUS] end of training..")
# Out:
# [STATUS] end of training..
